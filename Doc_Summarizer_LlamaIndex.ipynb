# %%
pip install llama-index-llms-groq llama-index-embeddings-huggingface
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 33.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 54.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 29.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.57.4
#     Uninstalling openai-1.57.4:
#       Successfully uninstalled openai-1.57.4
# ...

# %%
import os

# %%
GROQ_API_KEY = "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"

# %%
os.environ["GROQ_API_KEY"] = GROQ_API_KEY

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core import SummaryIndex
from llama_index.llms.groq import Groq
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbeddings
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-4930ef92aa59> in <cell line: 6>()
#       4 from llama_index.core.node_parser import SentenceSplitter
#       5 from llama_index.core import Settings
# ----> 6 from llama_index.embeddings.huggingface import HuggingFaceEmbeddings
#
# ImportError: cannot import name 'HuggingFaceEmbeddings' from 'llama_index.embeddings.huggingface' (/usr/local/lib/python3.10/dist-packages/llama_index/embeddings/huggingface/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip show llama_index
# Out:
# WARNING: Package(s) not found: llama_index

# %%
# !pip show huggingface_hub
# Out:
# Name: huggingface-hub
# Version: 0.27.0
# Summary: Client library to download and publish models, datasets and other repos on the huggingface.co hub
# Home-page: https://github.com/huggingface/huggingface_hub
# Author: Hugging Face, Inc.
# Author-email: julien@huggingface.co
# License: Apache
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, fsspec, packaging, pyyaml, requests, tqdm, typing-extensions
# Required-by: accelerate, diffusers, llama-index-embeddings-huggingface, peft, sentence-transformers, timm, tokenizers, transformers

# %%
# !pip show huggingface
# Out:
# WARNING: Package(s) not found: huggingface

# %%
# !pip install huggingface

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core import SummaryIndex
from llama_index.llms.groq import Groq
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbeddings
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-4930ef92aa59> in <cell line: 6>()
#       4 from llama_index.core.node_parser import SentenceSplitter
#       5 from llama_index.core import Settings
# ----> 6 from llama_index.embeddings.huggingface import HuggingFaceEmbeddings
#
# ImportError: cannot import name 'HuggingFaceEmbeddings' from 'llama_index.embeddings.huggingface' (/usr/local/lib/python3.10/dist-packages/llama_index/embeddings/huggingface/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install --upgrade llama-index-embeddings-huggingface

# %%
from llama_index.legacy.embeddings import HuggingFaceEmbeddings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-9456410720fc> in <cell line: 1>()
# ----> 1 from llama_index.legacy.embeddings import HuggingFaceEmbeddings
#
# ModuleNotFoundError: No module named 'llama_index.legacy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install --upgrade llama-index-embeddings-huggingface

from llama_index.core import SimpleDirectoryReader
from llama_index.core import SummaryIndex
from llama_index.llms.groq import Groq
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import Settings
from llama_index.legacy.embeddings import HuggingFaceEmbeddings
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-57a660f7b1d0> in <cell line: 8>()
#       6 from llama_index.core.node_parser import SentenceSplitter
#       7 from llama_index.core import Settings
# ----> 8 from llama_index.legacy.embeddings import HuggingFaceEmbeddings # Import from legacy if using an older version
#       9
#
# ModuleNotFoundError: No module named 'llama_index.legacy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install --upgrade llama-index-embeddings-huggingface

from llama_index.core import SimpleDirectoryReader
from llama_index.core import SummaryIndex
from llama_index.llms.groq import Groq
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import Settings
from llama_index.embeddings import HuggingFaceEmbeddings
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-17-136d1002588e> in <cell line: 8>()
#       6 from llama_index.core.node_parser import SentenceSplitter
#       7 from llama_index.core import Settings
# ----> 8 from llama_index.embeddings import HuggingFaceEmbeddings
#
# ImportError: cannot import name 'HuggingFaceEmbeddings' from 'llama_index.embeddings' (unknown location)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core import SummaryIndex
from llama_index.llms.groq import Groq
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# %%
llm = Groq(model= "llama-3.1-8b-instant")
Settings.llm = llm
Settings.embed_model = HuggingFaceEmbedding()
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/90.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
documents = SimpleDirectoryReader(input_files=["/All_you_need_is_attention.pdf"]).load_data()

# %%
# !pip install llama-index-readers-file
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 10.3 MB/s eta 0:00:00
# ...

# %%
from IPython import get_ipython
from IPython.display import display

# %%
# !pip show llama_index
# Out:
# WARNING: Package(s) not found: llama_index

# %%
print(type(documents))
# Out:
# <class 'list'>

# %%
len(documents)
# Out:
# 15

# %%
documents[1]
# Out:
# Document(id_='e87b6cd9-9991-4207-aed6-c7859c7f8618', embedding=None, metadata={'page_label': '2', 'file_name': 'All_you_need_is_attention.pdf', 'file_path': '/All_you_need_is_attention.pdf', 'file_type': 'application/pdf', 'file_size': 2215244, 'creation_date': '2025-01-04', 'last_modified_date': '2025-01-04'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='1 Introduction\nRecurrent neural networks, long short-term memory [13] and gated recurrent [7] neural networks\nin particular, have been firmly established as state of the art approaches in sequence modeling and\ntransduction problems such as language modeling and machine translation
# ...

# %%
splitter = SentenceSplitter(chunk_size = 2048)
nodes = splitter.get_nodes_from_documents(documents)

# %%
summary_index = SummaryIndex(nodes)

# %%
summary_query_engine = summary_index.as_query_engine(
    response_mode = "tree_summarize",
    use_async = True
)

# %%
response = summary_query_engine.query("What is this book about?")

# %%
print(response)
# Out:
# This book discusses a new approach to sequence transduction models, which are used in various tasks such as machine translation, language modeling, and text summarization. It presents a novel model architecture that relies on self-attention mechanisms to draw global dependencies between input and output sequences, and explores its design, implementation, and applications.

# %%
summary_index.storage_context.persist("Doc Summary Index")
